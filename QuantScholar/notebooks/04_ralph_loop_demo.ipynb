# %% [markdown]
# # QuantumScholar: Notebook 04 — Ralph Agentic Loop Live Demo
# Run an end-to-end autonomous optimization cycle: Collect ➔ Evaluate ➔ Diagnose ➔ Propose ➔ Experiment ➔ Promote.

# %%
import sys
import json
sys.path.append('..')
from agents.ralph_loop import RalphLoop

ralph = RalphLoop(
    golden_dataset_path='../evaluation/datasets/quantum_qa_golden.jsonl',
    feedback_log_path='../evaluation/datasets/user_feedback_logs.jsonl'
)

# Run single autonomous optimization cycle
cycle_summary = ralph.run_cycle(auto_promote=True)
print('\nCycle Summary Output:')
print(json.dumps(cycle_summary, indent=2))
